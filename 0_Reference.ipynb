# %% [markdown]
# LATEX:
# https://en.wikibooks.org/wiki/LaTeX/Mathematics
#
# http://jupyter-notebook.readthedocs.io/en/latest/examples/Notebook/Typesetting%20Equations.html
#
# https://github.com/ipython-contrib/jupyter_contrib_nbextensions/tree/master/src/jupyter_contrib_nbextensions/nbextensions/equation-numbering
#
# http://docs.sympy.org/latest/tutorial/printing.html
#
# http://www.scipy-lectures.org/packages/sympy.html#symbols
#
# https://github.com/sympy/sympy/wiki/Quick-examples
#
# https://matplotlib.org/users/pyplot_tutorial.html
#
# http://mattpap.github.io/scipy-2011-tutorial/html/gotchas.html
#
# PEP 8 -- Style Guide for Python Code: https://www.python.org/dev/peps/pep-0008/
#
# Productionizing and Deploying Data Science Projects
# https://www.continuum.io/blog/developer-blog/productionizing-and-deploying-data-science-projects
#
# https://github.com/jupyter-incubator/dashboards_server
#
# Static Interactive Widgets for IPython Notebooks
# https://jakevdp.github.io/blog/2013/12/05/static-interactive-widgets/

# %%
#to install modules not already here
#!pip install mpmath

#after it's installed
#import mpmath

#!pip install sympy
# Out:
# ...
#     100% |████████████████████████████████| 4.3MB 227kB/s
# ...
#     100% |████████████████████████████████| 501kB 1.9MB/s
# ...
# done
#   Stored in directory: /home/notebook/.cache/pip/wheels/05/93/22/2d0f59d842347b1f38df0d3f7a3870586df60568d2a49d94c5
# done
#   Stored in directory: /home/notebook/.cache/pip/wheels/02/2b/99/cd867d5da48d951118a8020e86c0c12a65022702426582d4b8
# Successfully built sympy mpmath
# ...

# %%
#!pip install tabulate

from tabulate import tabulate
from IPython.display import HTML
table = [["Sun",696000,1989100000],
         ["Earth",6371,5973.6],
         ["Moon",1737,73.5],
         ["Mars",3390,641.85]]
display(HTML(tabulate(table, tablefmt='html')))

# %%
#print prettier output
init_printing(use_unicode=True)

# %%
#clear out everything
# %reset -f

import math
import sympy
from sympy import * #import everything
from __future__ import division
from sympy.abc import *
import numpy as np
import matplotlib.pyplot as plt
import platform
from IPython.display import display

init_printing() #print prettier output

#https://matplotlib.org/users/pyplot_tutorial.html
# %matplotlib inline 

#from IPython.core.interactiveshell import InteractiveShell #show all output
#InteractiveShell.ast_node_interactivity = "all"

print("Python version = %s" %platform.python_version())
print("Sympy verion = %s" %sympy.__version__)
# Out:
# Python version = 3.4.3
# Sympy verion = 1.0

# %%
import platform
print("Python version = %s" %platform.python_version())
print("Sympy verion = %s" %sympy.__version__)
# Out:
# Python version = 3.4.3
# Sympy verion = 1.0

# %%
eq1=Eq(x,y)
eq2=Eq(x,5)
display(eq1)
display(eq2)
result1 = solve(eq2,x,dict=1) #solve eq2 for x, output dictionary object
display(result1)
eq1.subs(solve(eq2,x,dict=1)[0])
result2 = eq1.subs(result1[0]) #substitute the first item in the dictionary object
display(result2)
solve((eq1,eq2), exclude=(x,))
# Out:
# x = y
# x = 5
# [{x: 5}]
# 5 = y
# {y: x}

# %% [markdown]
# Drag and drop local files onto GUI for DataScientistWorkbench to load them

# %%
from UnitConversion import * #custom .py file with unit conversions

# %%
funCtoF(100)
# Out:
# 212.0

# %%
#clear out everything
# %reset -f
import math
from sympy import * #import everything
from __future__ import division
from sympy.abc import *
import numpy as np
import matplotlib.pyplot as plt
import platform
from IPython.display import display
from UnitConversion import * #custom .py file with unit conversions
init_printing() #print prettier output
# %matplotlib inline

# %%
dir(sympy.abc); #remove semicolon to show full list of options

# %% [markdown]
# # Plotting
#
# http://www.scipy-lectures.org/intro/matplotlib/matplotlib.html

# %%
X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)
plt.plot(X, C)
plt.plot(X, S)
plt.show()

# %%
# Create a figure of size 8x6 inches, 80 dots per inch
plt.figure(figsize=(8, 6), dpi=80)

# Create a new subplot from a grid of 1x1
plt.subplot(1, 1, 1)

X = np.linspace(-np.pi, np.pi, 256, endpoint=True)
C, S = np.cos(X), np.sin(X)

# Plot cosine with a blue continuous line of width 1 (pixels)
plt.plot(X, C, color="red", linewidth=3.0, linestyle="-", label="cosine")

# Plot sine with a green continuous line of width 1 (pixels)
plt.plot(X, S, color="green", linewidth=1.0, linestyle="-", label="sine")

# Set x limits
plt.xlim(-4.0, 4.0)

# Set x ticks
#plt.xticks(np.linspace(-4, 4, 9, endpoint=True))
plt.xticks([-np.pi, -np.pi/2, 0, np.pi/2, np.pi],[r'$-\pi$', r'$-\pi/2$', r'$0$', r'$+\pi/2$', r'$+\pi$'])

# Set y limits
plt.ylim(-1.0, 1.0)

# Set y ticks
#plt.yticks(np.linspace(-1, 1, 5, endpoint=True))
plt.yticks([-1, 0, +1],[r'$-1$', r'$0$', r'$+1$'])


#adjust spines
ax = plt.gca()  # gca stands for 'get current axis'
ax.spines['right'].set_color('none')
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))


#legend
plt.legend(loc='upper left')



#annotate points
t = 2 * np.pi / 3
plt.plot([t, t], [0, np.cos(t)], color='blue', linewidth=2.5, linestyle="--")
plt.scatter([t, ], [np.cos(t), ], 50, color='blue')

plt.annotate(r'$sin(\frac{2\pi}{3})=\frac{\sqrt{3}}{2}$',
             xy=(t, np.sin(t)), xycoords='data',
             xytext=(+10, +30), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))

plt.plot([t, t],[0, np.sin(t)], color='red', linewidth=2.5, linestyle="--")
plt.scatter([t, ],[np.sin(t), ], 50, color='red')

plt.annotate(r'$cos(\frac{2\pi}{3})=-\frac{1}{2}$',
             xy=(t, np.cos(t)), xycoords='data',
             xytext=(-90, -50), textcoords='offset points', fontsize=16,
             arrowprops=dict(arrowstyle="->", connectionstyle="arc3,rad=.2"))


#adjust label font size
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontsize(16)
    label.set_bbox(dict(facecolor='white', edgecolor='None', alpha=0.65)) #adjusts box color, edge, transparency


    

#A “figure” in matplotlib means the whole window in the user interface. Within this figure there can be “subplots”    
    

# Save figure using 72 dots per inch
# plt.savefig("exercice_2.png", dpi=72)

# Show result on screen
plt.show()

# %% [markdown]
# # Widgets Practice
#
# http://nbviewer.jupyter.org/github/jupyter-widgets/ipywidgets/blob/master/docs/source/examples/Widget%20Basics.ipynb
#
# http://ipywidgets.readthedocs.io/en/latest/embedding.html
#
# http://nbviewer.jupyter.org/github/jupyter-widgets/ipywidgets/blob/master/docs/source/examples/Widget%20List.ipynb
#
# http://ipywidgets.readthedocs.io/en/latest/examples/Widget%20Styling.html

# %%
from ipywidgets import *
#from ipywidgets import Button, HBox, VBox

# %%
IntSlider()

# %%
from IPython.display import display
w = IntSlider()
display(w)

# %%
w1 = widgets.IntSlider(
    value=7,
    min=0,
    max=100,
    step=1,
    description='My Slider:',
    disabled=False,
    continuous_update=False,
    orientation='horizontal',
    readout=True,
    readout_format='i',
    slider_color='white'
)
w2 = widgets.Checkbox(
    value=False,
    description='Check me',
    disabled=False
)
display(w2,w1)

# %%
words = ['correct', 'horse', 'battery', 'staple']
items = [Button(description=w) for w in words]

HBox([VBox([w1, w2]), VBox([items[2], items[3]])])

# %% [markdown]
# # Example from https://blog.dominodatalab.com/interactive-dashboards-in-jupyter/

# %%
# %matplotlib notebook
import pandas as pd
import matplotlib.pyplot as plt
from ipywidgets import *
from IPython.display import display
plt.style.use('ggplot')

# %%
NUMBER_OF_PINGS = 4

text = widgets.Text(description="Domain to ping", width=200)
display(text)

data = pd.DataFrame()
x = range(1,NUMBER_OF_PINGS+1)
plots = dict()
fig, ax = plt.subplots()
plt.xlabel('iterations')
plt.ylabel('ms')
plt.xticks(x)
plt.show()

checkboxes = []
cb_container = widgets.HBox()
display(cb_container)

button = widgets.Button(description="Update the graph")


def handle_submit(sender):
    res = !ping -c {NUMBER_OF_PINGS} {text.value}
    hits = res.grep('64 bytes').fields(-2).s.replace("time=","").split()
    if len(hits) == 0:
        print ("Domain gave error on pinging")
    else:
        data[text.value] = hits
        data[text.value] = data[text.value].astype(float)
        plots[text.value], = ax.plot(x, data[text.value], label=text.value)
        plt.legend()
        plt.draw()
        checkboxes.append(widgets.Checkbox(description = text.value, value=True, width=90))
        cb_container.children=[i for i in checkboxes]
        if len(checkboxes) ==1:
            display(button)
      
def on_button_clicked(b):
    for c in cb_container.children:
        if not c.value:
            plots[c.description].set_visible(False)
        else:
            plots[c.description].set_visible(True)
    plt.legend()
    plt.draw()

button.on_click(on_button_clicked)
text.on_submit(handle_submit)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
