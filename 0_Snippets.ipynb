# %%
#To disable autoclosing brackets, run in a notebook:

from notebook.services.config import ConfigManager
c = ConfigManager()
c.update('notebook', {"CodeCell": {"cm_config": {"autoCloseBrackets": False}}})
# Out:
# {'load_extensions': {'equation-numbering/main': True,
#   'python-markdown/main': True,
#   'toc2/main': True,
#   'hide_input_all/main': True,
#   'hide_input/main': True,
#   'codefolding/main': True,
#   'latex_envs/latex_envs': False},
#  'CodeCell': {'cm_config': {'autoCloseBrackets': False}}}

# %% [markdown]
# \begin{equation}
# \sigma = \left(\frac{\sigma_x}{2}\right) + \left[\sqrt{\left(\frac{\sigma_x}{2}\right)^2 + \left(\tau_{xy}\right)}\right]
# \label{myLabel27}
# \end{equation}

# %% [markdown]
# As shown in Equation \ref{myLabel27} blah blah blah

# %%
#resets the namespace by removing all names defined by the user, if called without arguments
#-f force reset without asking for confirmation
# %reset -f

# %%
#show all interactive output, not just the last result
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
image = mpimg.imread("images/Heli_fenestron.png")
plt.imshow(image)
plt.show()

# %% [markdown]
# # SectionName

# %% [markdown]
# Click to go to a this specific named section [Link to Section Name](#SectionName)

# %% [markdown]
# <center id="Figure_01">Figure</center>

# %% [markdown]
# [Figure 1](#Figure_01)

# %% [markdown]
# This is a example of footnote[<sup>1</sup>](#fn1). Another footnote[<sup>2</sup>](#fn2).
#
# <span id="fn1"> footnote 1</span>
# <span id="fn2"> footnote 2</span>

# %% [markdown]
# This is a example of footnote and tooltip[<sup>1</sup>](#fn1 "footnote and tooltip 1").
# Another footnote[<sup>2</sup>](#fn2).
# Another tooltip[<sup>3</sup>](#_blank "tooltip 3").

# %% [markdown]
# <span id="fn1">footnote and tooltip 1</span>
#
# <span id="fn2">footnote 2</span>

# %% [markdown]
# Reference style links **only work within the same cell**
#
# I get 10 times more traffic from [Google][1] than from
# [Yahoo][2] or [MSN][3].
#
# [1]: http://google.com/        "Google"
# [2]: http://search.yahoo.com/  "Yahoo Search"
# [3]: http://search.msn.com/    "MSN Search"
#
#
# I start my morning with a cup of coffee and
# [The New York Times][NY Times].
#
# [ny times]: http://www.nytimes.com/

# %% [markdown]
# Regular link
# [click me](https://en.wikipedia.org "Wikipedia")

# %% [markdown]
# Here's an anchor. Could be any tag: div span cite a...
#
# <div id="idAnchor">optional stuff in the anchor</div>

# %% [markdown]
# Here's a link to that anchor
#
# [Go to Anchor](#idAnchor)
#
# [Go to Anchor with Tooltip Title](#idAnchor "Extra Title")

# %% [markdown]
# Works for PDF export but not regular rendering[^noteA]
#
# [^noteA]: A footnote marker cannot contain any spaces.

# %%
def funFtoK(fTempF):
    """converts F to K"""
    fTempK = (fTempF + 459.67)*5/9
    return fTempK

def funKtoF(fTempK):
    """converts K to F"""
    fTempF = fTempK*9/5 - 459.67
    return fTempF

def funCtoK(fTempC):
    """converts C to K"""
    fTempK = fTempC + 273.15
    return fTempK

def funINtoM(fLengthIN):
    """converts in to M"""
    fLengthM = fLengthIN * 0.0254
    return fLengthM

# %%
funCtoK(0)
# Out:
# 273.15
